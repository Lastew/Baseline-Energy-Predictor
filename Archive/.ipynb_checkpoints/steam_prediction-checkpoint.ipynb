# %% [markdown]
# # Examplary office Chilled Water consumption prediction usning LSTM Model

# %% [markdown]
# Energy consumption forecasting for buildings has immense value in energy efficiency and sustainability research. Accurate energy forecasting models have numerous implications in planning and energy optimization of buildings and campuses. For new buildings, where past recorded data is unavailable, computer simulation methods are used for energy analysis and forecasting future scenarios. However, for existing buildings with historically recorded time series energy data, statistical and machine learning techniques have proved to be more accurate and quick

# %% [markdown]
# ## Imports

# %%
# Data analysis packages:
import pandas as pd
import numpy as np
pd.set_option('display.float_format', lambda x: '%.3f'%x)

# Visualization packages:
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates

import warnings
import itertools
import datetime as dt
from IPython.display import HTML # to see everything
plt.style.use('seaborn-darkgrid')
warnings.filterwarnings("ignore")

# %% [markdown]
# Import sklearn and statsmodels

# %%
# import sklearn 
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Import tensorflow and Keras

# %%
import tensorflow as tf

# import Sequential
from tensorflow.python.keras.models import Sequential, load_model
from tensorflow.python.keras.layers import Input, Dense, LSTM, Embedding, Dropout
from tensorflow.python.keras.optimizers import RMSprop
from tensorflow.python.keras.callbacks import (EarlyStopping, ModelCheckpoint,
                                               TensorBoard, ReduceLROnPlateau, CSVLogger)
# print 
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.0.0-beta0
# 2.2.4-tf

# %% [markdown]
# Import my functions

# %%
# import plots as p
import supervised_learning as sl
# helper_functions as hf 
import visualization as vis
# import data_prep as dp
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load Dataset -- Steam

# %%
office = pd.read_csv('data_folder/office_data.csv')#, index_col=['timestamp'], parse_dates=['timestamp'])
office = pd.read_csv('data_folder/office_1249.csv', index_col=['timestamp'], parse_dates=['timestamp'])
usecols =['meter', 'meter_reading', 'air_temperature', 'cloud_coverage', 'dew_temperature','precip_depth_1_hr', 'sea_level_pressure', 'wind_direction', 'wind_speed']
office = office[usecols]
print('Dataset record for building_id = 1249:', office.shape)
office.head(3)
# Out:
# Dataset record for building_id = 1249: (35136, 9)
#             meter  meter_reading  air_temperature  cloud_coverage  \
# timestamp
# 2016-01-01      0        299.000              nan             nan
# 2016-01-01      1        695.555              nan             nan
# 2016-01-01      2        899.640              nan             nan
#
#             dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# timestamp
# 2016-01-01              nan                nan                 nan
# 2016-01-01              nan                nan                 nan
# 2016-01-01              nan                nan                 nan
#
#             wind_direction  wind_speed
# timestamp
# 2016-01-01             nan         nan
# 2016-01-01             nan         nan
# 2016-01-01             nan         nan

# %%
# forward and backward fill for missing time sereis observations
office_temp = office.ffill()
office_data = office_temp.bfill()
office_data.head(3)
# Out:
#             meter  meter_reading  air_temperature  cloud_coverage  \
# timestamp
# 2016-01-01      0        299.000            5.600           0.000
# 2016-01-01      1        695.555            5.600           0.000
# 2016-01-01      2        899.640            5.600           0.000
#
#             dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# timestamp
# 2016-01-01           -0.600              0.000            1019.500
# 2016-01-01           -0.600              0.000            1019.500
# 2016-01-01           -0.600              0.000            1019.500
#
#             wind_direction  wind_speed
# timestamp
# 2016-01-01         300.000       2.600
# 2016-01-01         300.000       2.600
# 2016-01-01         300.000       2.600

# %%
# office_data.isna().sum()

# %% [markdown]
# now we do not have any missing values, I can take out the electricity consumption for this machine learning project and do some explanatory data analysis

# %%
# electricity constumption for building_id 1249
steam_consumption = office_data[office_data['meter']==2]
steam_consumption.drop(columns=['meter'], inplace=True)
print(steam_consumption.shape)
steam_consumption.head(3)
# Out:
# (8784, 8)
#                      meter_reading  air_temperature  cloud_coverage  \
# timestamp
# 2016-01-01 00:00:00        899.640            5.600           0.000
# 2016-01-01 01:00:00       1019.590            5.600           0.000
# 2016-01-01 02:00:00       1319.470            5.600           4.000
#
#                      dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# timestamp
# 2016-01-01 00:00:00           -0.600              0.000            1019.500
# 2016-01-01 01:00:00           -0.600              0.000            1019.500
# 2016-01-01 02:00:00           -0.600              0.000            1019.500
#
#                      wind_direction  wind_speed
# timestamp
# 2016-01-01 00:00:00         300.000       2.600
# 2016-01-01 01:00:00         300.000       2.600
# 2016-01-01 02:00:00         300.000       2.600

# %%
steam_consumption.isin([0]).sum()
# Out:
# meter_reading           93
# air_temperature        127
# cloud_coverage        5883
# dew_temperature        152
# precip_depth_1_hr     7791
# sea_level_pressure       0
# wind_direction        1243
# wind_speed            1190
# dtype: int64

# %%
# Check if dataframe has a zero element
# elec_consumption['wind_direction'].isin([0]).sum() #any().any()

# %% [markdown]
# ## Exploratory Data Analysis or (EDA)

# %%
# %load -r 14-27 visualization.py

# %% [markdown]
# The energy consumption is in kWh (or equivalent). Note that this is real data with measurement error, which we expect will impose a baseline level of modeling error.

# %%
# plot 
# vis.median_meter_reading(office_data)
# plt.savefig('image/meter_reading_by_type')

# %%
# office_data.head()

# %%
# fig, ax = plt.subplots(figsize=(6, 13), subplot_kw=dict(aspect="equal"))
labels = 'Electricity', 'Chilled water', 'Steam', 'Hotwater'
sizes = list(office_data.groupby(by='meter')['meter_reading'].sum())
# colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, textprops={'fontsize':30})
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
# plt.title('percent energy cosumption by meter type')
plt.show()
# plt.savefig('image/pie_chart.png')

# %% [markdown]
# ### Box plots and outlier detection

# %%
steam_consumption['meter_reading'].replace(to_replace=0, method='ffill', inplace=True)
# red_square = dict(markerfacecolor='r', marker='s')
# data=pd.Series(np.random.randn(100))
# chw_consumption['meter_reading'].clip(lower=chw_consumption['meter_reading'].quantile(0.05), upper=chw_consumption['meter_reading'].quantile(0.95))
ax = sns.boxplot(x=steam_consumption["meter_reading"])

# %%
# B=plt.boxplot(steam_consumption.meter_reading)
# [item.get_ydata() for item in B['whiskers']]

# %%
steam_consumption['meter_reading'].plot()

# %%
steam_consumption.isin([0]).sum()
# Out:
# meter_reading            0
# air_temperature        127
# cloud_coverage        5883
# dew_temperature        152
# precip_depth_1_hr     7791
# sea_level_pressure       0
# wind_direction        1243
# wind_speed            1190
# dtype: int64

# %%
# B=plt.boxplot(chw_consumption.meter_reading)
# [item.get_ydata() for item in B['whiskers']]
whiskers_top = 2500
whiskers_bottom = 100
# median = steam_consumption.loc[chw_consumption['meter_reading'] < whiskers, 'meter_reading'].median()
steam_consumption['meter_reading'] = np.where(steam_consumption['meter_reading'] < whiskers_bottom, median, steam_consumption['meter_reading'])
steam_consumption['meter_reading'] = np.where(steam_consumption['meter_reading'] > whiskers_top, median, steam_consumption['meter_reading'])
ax = sns.boxplot(x=steam_consumption["meter_reading"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-856ba53993e6> in <module>
#       4 whiskers_bottom = 100
#       5 # median = steam_consumption.loc[chw_consumption['meter_reading'] < whiskers, 'meter_reading'].median()
# ----> 6 steam_consumption['meter_reading'] = np.where(steam_consumption['meter_reading'] < whiskers_bottom, median, steam_consumption['meter_reading'])
#       7 steam_consumption['meter_reading'] = np.where(steam_consumption['meter_reading'] > whiskers_top, median, steam_consumption['meter_reading'])
#       8 ax = sns.boxplot(x=steam_consumption["meter_reading"])
#
# NameError: name 'median' is not defined

# %%
sns.countplot(office_data['meter_type'], order=office_data['meter_type'].value_counts().index)
plt.title('Distribution of Meter Id Code')
plt.xlabel('Meter Id Code')
plt.ylabel('Frequency');

# %%
# %load -r 97-128 visualization.py

# %%
# seasonal_decompose_plot()

# %%
import plotly.graph_objects as go
import plotly
from plotly.subplots import make_subplots
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !jupyter labextension install jupyterlab-dash@0.1.0-alpha.3 --user

# %%
# Make subplot figure 
fig = make_subplots(specs=[[{"secondary_y": True}]])
# Add traces; weekday and weekend aggregate rides
fig.add_trace(go.Scatter(x=elec_consumption.index, y=elec_consumption['meter_reading'], name="Actual Number of Rides Each Hour",
                         line_color='red'))
fig.add_trace(go.Scatter(x=elec_consumption.index, y=elec_consumption['meter_reading'], name="Predicted Rides Each Hour",
                         line_color='black'), secondary_y=False)
fig.update_layout(title_text='Predicted and Actual Rides Each Hour')
# Set x-axis title
fig.update_xaxes(title_text="Hour of Day")
# Set y-axes titles
fig.update_yaxes(title_text="<b>Numer of Rides</b> initiated", secondary_y=False)
fig.update_yaxes(title_text="<b>Rides</b>", secondary_y=False)
# Include x-axis slider
fig.update_layout(xaxis_rangeslider_visible=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-701b9504a88c> in <module>
#       2 fig = make_subplots(specs=[[{"secondary_y": True}]])
#       3 # Add traces; weekday and weekend aggregate rides
# ----> 4 fig.add_trace(go.Scatter(x=elec_consumption.index, y=elec_consumption['meter_reading'], name="Actual Number of Rides Each Hour",
#       5                          line_color='red'))
#       6 fig.add_trace(go.Scatter(x=elec_consumption.index, y=elec_consumption['meter_reading'], name="Predicted Rides Each Hour",
#
# NameError: name 'elec_consumption' is not defined

# %% [markdown]
# ### Stationarity

# %%
import testing_functions as testf

# %% [markdown]
# checking statinarlity and comfiriming all are statinary

# %%
# col_len = list(steam_consumption.columns)
# for i in col_len:
#     testf.test_stationarity(steam_consumption[i])

# %%
temp_df = office[['meter_reading', 'meter']]
meter_mapping = {0: 'electricity', 1: 'chilledwater', 2: 'steam', 3: 'hotwater'}
temp_df['meter_type'] = temp_df['meter'].map(meter_mapping)
building_1249 = temp_df.pivot(columns='meter_type', values='meter_reading', )
# building_1249.head()
daily = building_1249.resample('D').mean()
daily.plot(style=[':', '--', '-', '.'], figsize=(16,10), grid=True)
plt.ylabel('Daily avarege energy consumption [MWh]');

# %%
# %load -r 81-95 visualization.py

# %%
rolling_statistics(daily, col='electricity')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a17c05eb992b> in <module>
# ----> 1 rolling_statistics(daily, col='electricity')
#
# NameError: name 'rolling_statistics' is not defined

# %% [markdown]
# test stationarity

# %%
# %load -r 131-146 visualization.py

# %% [markdown]
# plot acf and pacf plots

# %%
# %load -r 148-157 visualization.py

# %%
# %load -r 160-167 visualization.py

# %%
from statsmodels.tsa.stattools import adfuller

# %%
stationarity_autocorrelation_test_original(daily, col='electricity')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-675d34f4d431> in <module>
# ----> 1 stationarity_autocorrelation_test_original(daily, col='electricity')
#
# NameError: name 'stationarity_autocorrelation_test_original' is not defined

# %%
import statsmodels.api as sm

# %% [markdown]
# plot a time series plot

# %%
y = elec_consumption.meter_reading
vis.tsplot(y, 'Electric Consumption [kWh]', lags=40)
# %load -r 171-188 visualization.py

# %% [markdown]
# ### Seasonality

# %% [markdown]
# ## Features and labels
# for this capstone project, I wanted to build a model that will predict the future energy consumption and air temperature variation as a function of all other eight features.

# %%
target_names = ['meter_reading']#, 'air_temperature']
shift_days = 1
shift_steps = shift_days * 24 # I wanted to shift the record by shift_steps hours.
df_targets = steam_consumption[target_names].shift(-shift_steps)
df_targets.head(3)
# Out:
#                      meter_reading
# timestamp
# 2016-01-01 00:00:00       1259.500
# 2016-01-01 01:00:00       1259.500
# 2016-01-01 02:00:00       1259.500

# %% [markdown]
# to check we successfully shifted by 24 hours, I took the 24 to 27 records from the original data

# %%
# check the raws from 24- 27
steam_consumption[target_names].iloc[24:27]
# Out:
#                      meter_reading
# timestamp
# 2016-01-02 00:00:00       1259.500
# 2016-01-02 01:00:00       1259.500
# 2016-01-02 02:00:00       1259.500

# %% [markdown]
# good! new we succesfully shifted by 24 hours, let us split the data set into feature and target.

# %%
# features
x_data = steam_consumption.values[0:-shift_steps]
print('    Feature Shape:', x_data.shape)
 
# target
y_data = df_targets.values[:-shift_steps]
print('    Target Shape:', y_data.shape)
# Out:
#     Feature Shape: (8760, 8)
#     Target Shape: (8760, 1)

# %%
steam_consumption.head(3)
# Out:
#                      meter_reading  air_temperature  cloud_coverage  \
# timestamp
# 2016-01-01 00:00:00        899.640            5.600           0.000
# 2016-01-01 01:00:00       1019.590            5.600           0.000
# 2016-01-01 02:00:00       1319.470            5.600           4.000
#
#                      dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# timestamp
# 2016-01-01 00:00:00           -0.600              0.000            1019.500
# 2016-01-01 01:00:00           -0.600              0.000            1019.500
# 2016-01-01 02:00:00           -0.600              0.000            1019.500
#
#                      wind_direction  wind_speed
# timestamp
# 2016-01-01 00:00:00         300.000       2.600
# 2016-01-01 01:00:00         300.000       2.600
# 2016-01-01 02:00:00         300.000       2.600

# %%
# These are the input-signals for the training- and test-sets:
num_data = len(x_data)
train_split = 0.85
num_train = int(train_split * num_data)
num_test = num_data - num_train
print('Training observations:', num_train)
print('Validation observations:', num_test)
x_train = x_data[0:num_train]
x_test  = x_data[num_train:]
print('Total observations:', (len(x_train) + len(x_test)))
# Out:
# Training observations: 7446
# Validation observations: 1314
# Total observations: 8760

# %%
# Check the shape
x_train.shape, x_test.shape
# Out:
# ((7446, 8), (1314, 8))

# %%
# These are the output-signals for the training- and test-sets:
y_train = y_data[0:num_train]
y_test = y_data[num_train:]
print('Total test observations:', (len(y_train) + len(y_test)))
y_train.shape, y_test.shape
# Out:
# Total test observations: 8760
# ((7446, 1), (1314, 1))

# %%
num_x_signals = x_data.shape[1] # 8
num_y_signals = y_data.shape[1] # 2
print('Number of input-signals:', num_x_signals, 'and shape:', x_train.shape )
print('Number of output-signals:', num_y_signals, 'and shape', y_train.shape)
# Out:
# Number of input-signals: 8 and shape: (7446, 8)
# Number of output-signals: 1 and shape (7446, 1)

# %% [markdown]
# ## Scaled Data

# %%
# x_data[24:27] # I shifted the data by one day

# %%
print('Min and Max x_train data')
print('    Min:', np.min(x_train))
print('    Max:', np.max(x_train))
x_scaler = MinMaxScaler() # feature_range=(0, 1)
x_scaled_train = x_scaler.fit_transform(x_train)
print('Min and Max x_train_scaled data')
print('    Min:', np.min(x_scaled_train))
print('    Max:', np.max(x_scaled_train))
# Out:
# Min and Max x_train data
#     Min: -25.6
#     Max: 7556.98
# Min and Max x_train_scaled data
#     Min: 0.0
#     Max: 1.0

# %%
x_scaled_test = x_scaler.transform(x_test)
print('Min and Max x_test data')
print('    Min:', np.min(x_test))
print('    Max:', np.max(x_test))

# target MinMaxScaler
y_scaler = MinMaxScaler() # feature_range=(-1, 1)
y_scaled_train = y_scaler.fit_transform(y_train)
y_scaled_test = y_scaler.transform(y_test)
print('Min and Max y_test_scaled data')
print('    Min:', np.min(y_scaled_test))
print('    Max:', np.max(y_scaled_test))
# Out:
# Min and Max x_test data
#     Min: -23.3
#     Max: 2628.11
# Min and Max y_test_scaled data
#     Min: 0.004301585006490591
#     Max: 0.34674171175578944

# %%
print(x_scaled_train.shape)
print(y_scaled_train.shape)
print('-------')
print(x_scaled_test.shape)
print(y_scaled_test.shape)
# y_train_scaled
# Out:
# (7446, 8)
# (7446, 1)
# -------
# (1314, 8)
# (1314, 1)

# %% [markdown]
# The data we have now is one long-time series with 20 input signals so that each time step has 8 input signals and 2 output signals

# %% [markdown]
# ## Data Generator

# %%
print(x_scaled_train.shape)
print(y_scaled_train.shape)
# Out:
# (7446, 8)
# (7446, 1)

# %% [markdown]
# call the batch generator function and create a training bach

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, num_x_signals)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length, num_y_signals)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = x_scaled_train[idx:idx+sequence_length]
            y_batch[i] = y_scaled_train[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %% [markdown]
# The above function will break the long-time series signal into small subsequences and create a batch so that we can use that for training the network

# %% [markdown]
# ```python
# reshape input to be [samples, time steps, features]
# ```

# %%
# reshape input to be [samples, time steps, features]
batch_size = 64 # batch size of 32 is a good starting point, and you should also try with 64, 128, and 256.
sequence_length = shift_steps # 24 * 7

# create the batch-generator
generator = batch_generator(batch_size, sequence_length)

# test the batch-generator to see if it works 
x_batch, y_batch = next(generator)
print(x_batch.shape)
print(y_batch.shape)
# Out:
# (64, 24, 8)
# (64, 24, 1)

# %% [markdown]
# we get a batch output where we have a batch size of 64 sequences, each sequence has 24, and 8 input signals and 2 output signals.

# %%
signal_list = list(chw_consumption.columns)
print('length of signals:', len(signal_list))

# signal plot for electricity consumption
batch = 0   # First sequence in the batch.
signal = 0  # First signal from the 8 input-signals.
seq = x_batch[batch, :, signal]
plt.plot(seq);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-993a9af22f7b> in <module>
# ----> 1 signal_list = list(chw_consumption.columns)
#       2 print('length of signals:', len(signal_list))
#       3
#       4 # signal plot for electricity consumption
#       5 batch = 0   # First sequence in the batch.
#
# NameError: name 'chw_consumption' is not defined

# %%
# y plot for electricity consumption
seq = y_batch[batch, :, signal] # only two output signals
plt.plot(seq);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-11b8b8d6e219> in <module>
#       1 # y plot for electricity consumption
# ----> 2 seq = y_batch[batch, :, signal] # only two output signals
#       3 plt.plot(seq);
#
# NameError: name 'batch' is not defined

# %% [markdown]
# I create a validation dataset from the testing data

# %%
validation_data = (np.expand_dims(x_scaled_test, axis=0),
                   np.expand_dims(y_scaled_test, axis=0))

# %%
print('x_test_validation', validation_data[0].shape)
print('y_test_validation', validation_data[1].shape)
# Out:
# x_test_validation (1, 1314, 8)
# y_test_validation (1, 1314, 1)

# %% [markdown]
# ## Create the Recurrent Neural Network Architecture

# %%
# from tf.keras.models import Sequential  # This does not work!
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Input, Dense, GRU, Embedding
from tensorflow.python.keras.optimizers import RMSprop
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau

# %% [markdown]
# ### Initalize the RNN
# Now let us instantiate an RNN model

# %%
# clear a model
tf.keras.backend.clear_session()

# %%
# Initializing RNN 
steam_dropout_model = Sequential()

# %% [markdown]
# #### Adding the LSTM layers and some Dropout regularization

# %%
from keras import regularizers

# %%
# Adding the first LSTM layer and some Dropout regularisation
steam_dropout_model.add(LSTM(units=100, return_sequences=True, dropout=0.2, #kernel_regularizer=regularizers.l2(0.01),
#                             activity_regularizer=regularizers.l1(0.01),
                            input_shape=(None, num_x_signals,)))
# steam_dropout_model.add(Dropout(0.4))
# model.summary()

# %%
# Adding the second LSTM layer and some Dropout regularisation
steam_dropout_model.add(LSTM(units=100, return_sequences=True, dropout=0.2 #kernel_regularizer=regularizers.l2(0.01), 
#                            activity_regularizer=regularizers.l1(0.01)
                            ))
# steam_dropout_model.add(Dropout(0.4))
# model.summary()

# %%
steam_dropout_model.add(Dense(num_y_signals, activation='sigmoid' #, kernel_regularizer=regularizers.l2(0.01),
#                              activity_regularizer=regularizers.l1(0.01)
                             ))

if False:
    from tensorflow.python.keras.initializers import RandomUniform

    # Maybe use lower init-ranges.
    init = RandomUniform(minval=-0.05, maxval=0.05) # I ca

    steam_dropout_model.add(Dense(num_y_signals,
                    activation='linear',
                    kernel_initializer=init))

# %% [markdown]
# ### Loss Function

# %%
warmup_steps = 50

# %% [markdown]
# load the loss_mse_warmup function below

# %%
# %load -r 41-63 supervised_learning.py

# %% [markdown]
# ### Compile Model

# %%
# optimizer = RMSprop(lr=1e-3)
# optimizer = tf.keras.optimizers.SGD(lr=1e-6, momentum=0.9)

# %%
# model.compile(loss=loss_mse_warmup, optimizer=optimizer, metrics=['acc'])
# chw_baseline_model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['acc'])
steam_dropout_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])
steam_dropout_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 100)         43600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 100)         80400
# _________________________________________________________________
# dense (Dense)                (None, None, 1)           101
# =================================================================
# Total params: 124,101
# Trainable params: 124,101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Callback Functions

# %%
# path_checkpoint = '23_checkpoint.keras'
# path_checkpoint = 'weights/model_weights.best.{epoch:02d}-{val_loss:.2f}.hdf5'
path_checkpoint = 'weights/model_weights_steam_dropout.h5'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                     monitor='val_loss',
                                      verbose=1,
                                      save_weights_only=True,
                                      save_best_only=True)
callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=5, verbose=1)

# %%
callback_tensorboard = TensorBoard(log_dir='./logs/',
                                   histogram_freq=0,
                                   write_graph=False) #'./23_logs/'

# %%
callback_reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-4,
                                       patience=0,
                                       verbose=1)

# %%
csv_logger = CSVLogger('logs/steam_dropout_model.csv')

# %%
# callback lists 
callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard,
             callback_reduce_lr,
             csv_logger] # check the logger

# %% [markdown]
# ### Fit the RNN to the training set

# %%
# %%time
steam_dropout_history = steam_dropout_model.fit_generator(generator=generator,
                    epochs=20,
                    steps_per_epoch=100,
                    validation_data=validation_data,
                    callbacks=callbacks)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#   1/100 [..............................] - ETA: 7:55 - loss: 0.1573 - mse: 0.1573WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.797602). Check your callbacks.
#  99/100 [============================>.] - ETA: 0s - loss: 0.0187 - mse: 0.0187
# Epoch 00001: val_loss improved from inf to 0.00409, saving model to weights/model_weights_steam_dropout.h5
# 100/100 [==============================] - 16s 164ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 2/20
#  99/100 [============================>.] - ETA: 0s - loss: 0.0036 - mse: 0.0036
# Epoch 00002: val_loss did not improve from 0.00409
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 3/20
#  99/100 [============================>.] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 00003: val_loss did not improve from 0.00409
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0001.
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 4/20
#  99/100 [============================>.] - ETA: 0s - loss: 0.0022 - mse: 0.0022
# Epoch 00004: val_loss did not improve from 0.00409
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 5/20
#  99/100 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 00005: val_loss did not improve from 0.00409
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 6/20
#  99/100 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 00006: val_loss did not improve from 0.00409
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 00006: early stopping
# CPU times: user 3min 31s, sys: 30.2 s, total: 4min 1s
# Wall time: 58.4 s

# %% [markdown]
# ### Evaluate the model

# %%
steam_dropout_model.evaluate(validation_data[0], validation_data[1])
# Out:
# 1/1 [==============================] - 2s 2s/sample - loss: 0.0042 - mse: 0.0042
# [0.004228194244205952, 0.0042281942]

# %%
steam_dropout_model.evaluate(x_batch, y_batch)
# Out:
# 64/64 [==============================] - 1s 14ms/sample - loss: 0.0015 - mse: 0.0015
# [0.0015242081135511398, 0.0015242081]

# %%
# evaluate training set
print(x_scaled_train.shape, y_scaled_train.shape)
x_sis = np.expand_dims(x_scaled_train, axis=0)
y_sis = np.expand_dims(y_scaled_train, axis=0)
print(x_sis.shape, y_sis.shape)
# model.evaluate(x_sis, y_sis)

# %%
# evaluate test set
steam_dropout_model.evaluate(validation_data[0], validation_data[1])
print('validation set should be a 3D arrray', 
      validation_data[0].shape, validation_data[1].shape)

# %%
# first_model = load_model('weights/first_model.h5')
# first_model.evaluate(validation_data[0], validation_data[1])

# %%
print(x_scaled_train.shape)
print(y_scaled_train.shape)
print('-----')
print(x_scaled_test.shape)
print(y_scaled_test.shape)
type(x_scaled_train)

# %%
# this is also a validation test
result = chw_baseline_model.evaluate(x=np.expand_dims(x_scaled_test, axis=0),
                        y=np.expand_dims(y_scaled_test, axis=0))

# %%
print("loss (test-set):", result)

# %%
training_score = chw_baseline_model.evaluate(x_sis, y_sis)

# %%
# If you have several metrics you can use this instead.
if False:
    for res, metric in zip(result, model.metrics_names):
        print("{0}: {1:.3e}".format(metric, res))

# %% [markdown]
# load plot comparision plot

# %%
# %load -r 30-66 visualization.py
def plot_comparison(start_idx, length=100, train=True, model=None):
    
    if train:
        # Use training-data.
        x = x_scaled_train
        y_true = y_train
    else:
        # Use test-data.
        x = x_scaled_train
        y_true = y_test
    
    end_idx = start_idx + length
    
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    x = np.expand_dims(x, axis=0)

    y_pred = model.predict(x)
    
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    for signal in range(len(target_names)):
        signal_pred = y_pred_rescaled[:, signal]

        signal_true = y_true[:, signal]

        plt.figure(figsize=(15,5))
        
        plt.plot(signal_true, label='true')
        plt.plot(signal_pred, label='pred')
       
        p = plt.axvspan(0, warmup_steps, facecolor='black', alpha=0.15)
       
        plt.ylabel(target_names[signal])
        plt.legend()
        plt.show()

# %%
plot_comparison(start_idx=4000, length=1000, train=True, model=steam_dropout_model)

# %% [markdown]
# ### Example from test set

# %%
plot_comparison(start_idx=1000, length=1000, train=False, model=steam_dropout_model)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
def calculate_errors(train=True, model=None):
    
    if train:
        # Use training-data.
        x = x_scaled_train
        y_true = y_train
        print('Traning data:')
    else:
        # Use test-data.
        x = x_scaled_test
        y_true = y_test
        print('Testing data:')
    
    x = np.expand_dims(x, axis=0)

    y_pred = model.predict(x)
    
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    for signal in range(len(target_names)):
        signal_pred = y_pred_rescaled[:, signal]

        signal_true = y_true[:, signal]
        
        print('    Mean Absolute Error:', mean_absolute_error(signal_true, signal_pred))
        print('    Root Mean Squared Error:',np.sqrt(mean_squared_error(signal_true, signal_pred)))

# %%
calculate_errors(train=True, model=steam_dropout_model)

# %%
calculate_errors(train=False, model=steam_dropout_model)

# %%
plt.figure(figsize=(10,5))
plt.plot(steam_dropout_history.history['loss'], label='Train Loss')
plt.plot(steam_dropout_history.history['val_loss'], label='Test Loss')
plt.title('Model train vs validation loss for steam', fontsize=20)
plt.ylabel('loss', fontsize=16)
plt.xlabel('epochs', fontsize=16)
plt.xticks(fontsize=12), plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=14)
# sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
# plt.savefig('image/model_loss_steam')
plt.show();

# %%
def plot_train_vs_val_loss(history=None):
    """
    plot model accuracy, comparing training and testing accuracies.
    Arguments:
        history: model history 
    Outputs:
        MSE loss plot 
    """
    fig = go.Figure()
    fig.add_trace(go.Scatter(y=history.history['loss'], name="Train Loss"))
    fig.add_trace(go.Scatter(y=history.history['val_loss'], name="Train Loss"))
    fig.update_layout(width=1000, height=500,
                      title= {'text': "Train vs validation loss (Steam)", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
                      xaxis_title="Epochs",
                      yaxis_title="Loss",
                      font=dict(family="Courier New, monospace", size=16, color='black')
                     )
    fig.write_image('image/train2.png')
    fig.show();

# %%
plot_train_vs_val_loss(history=steam_dropout_history)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-adf1d0fdf2cf> in <module>
# ----> 1 plot_train_vs_val_loss(history=steam_dropout_history)
#
# <ipython-input-106-1943d621973b> in plot_train_vs_val_loss(history)
#      16                       font=dict(family="Courier New, monospace", size=16, color='black')
#      17                      )
# ---> 18     fig.write_image('image/train2.png')
#      19     fig.show();
#
# /usr/local/lib/python3.5/dist-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    2815         import plotly.io as pio
#    2816
# -> 2817         return pio.write_image(self, *args, **kwargs)
#    2818
#    2819     # Static helpers
#
# /usr/local/lib/python3.5/dist-packages/plotly/io/_orca.py in write_image(fig, file, format, scale, width, height, validate)
#    1703     # Do this first so we don't create a file if image conversion fails
#    1704     img_data = to_image(
# -> 1705         fig, format=format, scale=scale, width=width, height=height, validate=validate
#    1706     )
#    1707
#
# /usr/local/lib/python3.5/dist-packages/plotly/io/_orca.py in to_image(fig, format, width, height, scale, validate)
#    1480     # Make sure orca sever is running
#    1481     # -------------------------------
# -> 1482     ensure_server()
#    1483
#    1484     # Handle defaults
#
# /usr/local/lib/python3.5/dist-packages/plotly/io/_orca.py in ensure_server()
#    1342     # Validate orca executable
#    1343     if status.state == "unvalidated":
# -> 1344         validate_executable()
#    1345
#    1346     # Acquire lock to make sure that we keep the properties of orca_state
#
# /usr/local/lib/python3.5/dist-packages/plotly/io/_orca.py in validate_executable()
#    1041                 executable=config.executable,
#    1042                 formatted_path=formatted_path,
# -> 1043                 instructions=install_location_instructions,
#    1044             )
#    1045         )
#
# ValueError:
# The orca executable is required to export figures as static images,
# but it could not be found on the system path.
#
# Searched for executable 'orca' on the following path:
#     /usr/local/cuda/bin
#     /usr/local/bin
#     /usr/bin
#     /bin
#     /usr/local/games
#     /usr/games
#
# If you haven't installed orca yet, you can do so using conda as follows:
#
#     $ conda install -c plotly plotly-orca
#
# Alternatively, see other installation methods in the orca project README at
# https://github.com/plotly/orca.
#
# After installation is complete, no further configuration should be needed.
#
# If you have installed orca, then for some reason plotly.py was unable to
# locate it. In this case, set the `plotly.io.orca.config.executable`
# property to the full path of your orca executable. For example:
#
#     >>> plotly.io.orca.config.executable = '/path/to/orca'
#
# After updating this executable property, try the export operation again.
# If it is successful then you may want to save this configuration so that it
# will be applied automatically in future sessions. You can do this as follows:
#
#     >>> plotly.io.orca.config.save()
#
# If you're still having trouble, feel free to ask for help on the forums at
# https://community.plot.ly/c/api/python

# %%
plt.figure(figsize=(10,5))
plt.plot(steam_dropout_history.history['acc'], label='Train Accuracy')
plt.plot(steam_dropout_history.history['val_acc'], label='Test Accuracy')
plt.title('Model train vs validation accuracy', fontsize=20)
plt.ylabel('accuracy', fontsize=16)
plt.xlabel('epochs', fontsize=16)
plt.xticks(fontsize=12), plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=14)
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
plt.show();

# %% [markdown]
# # # 2nd_LSTM Model
# this model uses an upgrade on batch size
# - softmax activation
# - optimizer adam
# - batch size 72

# %%
# reshape input to be [samples, time steps, features]
batch_size = 64
# sequence_length = shift_steps # 24 * 7

# create the batch-generator
generator = batch_generator(batch_size, sequence_length)

# test the batch-generator to see if it works 
x_batch, y_batch = next(generator)
print(x_batch.shape)
print(y_batch.shape)

# %%
# reshape input to be [samples, time steps, features]
# batch_size_2 = 30
# sequence_length = shift_steps # 24 * 7

# create the batch-generator
# generator_2 = batch_generator(batch_size_2, sequence_length)

# test the batch-generator to see if it works 
x_batch, y_batch = next(generator)
print(x_batch.shape)
print(y_batch.shape)

# %%
# clear a model
tf.keras.backend.clear_session()

# %%
# Initializing RNN 
chw_dropout_model = Sequential()

# %% [markdown]
# #### Adding the LSTM layers and some Dropout regularization

# %%
# Adding the first LSTM layer and some Dropout regularisation
chw_dropout_model.add(LSTM(units=50, return_sequences=True, #kernel_regularizer=regularizers.l2(0.01),
#                            activity_regularizer=regularizers.l1(0.01),
                           input_shape=(None, num_x_signals,)))
chw_dropout_model.add(Dropout(0.4))
# model.summary()

# %%
# Adding the second LSTM layer and some Dropout regularisation
chw_dropout_model.add(LSTM(units=50, return_sequences=True, #kernel_regularizer=regularizers.l2(0.01),
#                 activity_regularizer=regularizers.l1(0.01)
                          ))
chw_dropout_model.add(Dropout(0.4))
# model.summary()

# %%
chw_dropout_model.add(Dense(num_y_signals, activation='sigmoid', #kernel_regularizer=regularizers.l2(0.01),
#                 activity_regularizer=regularizers.l1(0.01)
                           ))

if False:
    from tensorflow.python.keras.initializers import RandomUniform

#     # Maybe use lower init-ranges.
    init = RandomUniform(minval=-0.05, maxval=0.05) # I ca

    chw_dropout_model.add(Dense(num_y_signals,
                                activation='linear', #kernel_regularizer=regularizers.l2(0.01), #linear
                                #activity_regularizer=regularizers.l1(0.01),
                                kernel_initializer=init))

# %%
# optimizer = RMSprop(lr=1e-3)
# optimizer = tf.keras.optimizers.SGD(lr=1e-6, momentum=0.9)

# %%
# model.compile(loss=loss_mse_warmup, optimizer=optimizer, metrics=['acc'])
chw_dropout_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['acc'])
chw_dropout_model.summary()

# %% [markdown]
# ### Fitting the model

# %%
csv_logger = CSVLogger('logs/chw_dropout_model.csv')

# %%
path_checkpoint = 'weights/model_weights_chw_dropout.h5'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                     monitor='val_loss',
                                      verbose=1,
                                      save_weights_only=True,
                                      save_best_only=True)

# %%
# callback lists 
callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard,
             callback_reduce_lr,
             csv_logger] # check the logger

# %%
# %%time
chw_dropout_history = chw_dropout_model.fit_generator(generator=generator,
                    epochs=20,
                    steps_per_epoch=50, #100,
                    validation_data=validation_data,
                    callbacks=callbacks)

# %% [markdown]
# # Evaluating the model

# %%
chw_dropout_model.evaluate(validation_data[0], validation_data[1])

# %%
chw_dropout_model.evaluate(x_batch, y_batch)

# %%
# x_sis.shape, y_sis.shape

# %%
# compare_cx = data.frame(
#     baseline_train = history.history['loss'],
#     baseline_val = history.history['val_loss'],
#     dropout_train = dropout_history.history['loss'],
#     dropout_val = dropout_history.history['val_loss'])
# ) %>%

# %%
plt.figure(figsize=(10,5))
plt.plot(chw_dropout_history.history['loss'], label='Train Loss')
plt.plot(chw_dropout_history.history['val_loss'], label='Test Loss')
plt.title('Model loss vs validation loss', fontsize=20)
plt.ylabel('loss', fontsize=16)
plt.xlabel('epochs', fontsize=16)
plt.xticks(fontsize=12), plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=14)
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
plt.show();

# %% [markdown]
# # Overfitting and underfitting
#
# The accuracy of our model on the validation data would peak after training for a number of epochs, and would then start decreasing.
#
# In other words, our model would overfit to the training data. Learning how to deal with overfitting is important. Although it’s often possible to achieve high accuracy on the training set, what we really want is to develop models that generalize well to testing data (or data they haven’t seen before).
#
# there are two common regularization techniques - weight regularization and dropout

# %%
# from builtins import *
# from pyensae.languages.rconverter import r2python

# %%
# !sudo pip install antlr4-python2-runtime

# %%
# !pip install pyensae --user
# !sudo pip install antlr4-python2-runtime

# %%
# list all data in history
print(chw_dropout_history.history.keys())
# summarize history for accuracy
plt.plot(chw_dropout_history.history['acc'])
plt.plot(chw_dropout_history.history['val_acc'])
plt.title('Model vs validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(chw_dropout_history.history['loss'])
plt.plot(chw_dropout_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def calculate_errors(train=True, model=None):
    
    if train:
        # Use training-data.
        x = x_scaled_train
        y_true = y_train
        print('Traning data:')
    else:
        # Use test-data.
        x = x_scaled_test
        y_true = y_test
        print('Testing data:')
    
    x = np.expand_dims(x, axis=0)

    y_pred = model.predict(x)
    
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    for signal in range(len(target_names)):
        signal_pred = y_pred_rescaled[:, signal]

        signal_true = y_true[:, signal]
        
        print('    Mean Absolute Error:', mean_absolute_error(signal_true, signal_pred))
        print('    Root Mean Squared Error:',np.sqrt(mean_squared_error(signal_true, signal_pred)))

# %%
plot_comparison(start_idx=4000, length=1000, train=True, model=chw_dropout_model)

# %% [markdown]
# ### Example from test set

# %%
plot_comparison(start_idx=1000, length=1000, train=False, model=chw_dropout_model)

# %%
calculate_errors(train=True, model=chw_baseline_model)

# %%
calculate_errors(train=True, model=chw_baseline_model)

# %% [markdown]
# ### Measuring and ploting RMSE

# %% [markdown]
# #### Finding Fedaral Holidays

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
df = df_elc.copy()
df = df.reset_index()
df['days'] = df.timestamp.apply(lambda x:1 if x.dayofweek > 5 else 0)
df.days.value_counts()

# %%
cal = calendar()
holidays = cal.holidays(start = df.timestamp.min(), end = df.timestamp.max())
df["holiday"] = df.timestamp.isin(holidays).astype('int')
df.head(3)

# %% [markdown]
# #### -- start

# %% [markdown]
# As a first step, I instantiate the Sequential class. This will be my model class and I will add LSTM, Dropout and Dense layers to this model.

# %% [markdown]
# the output of the last layer is a tensor with an aritrary batch size and arbitrary sequance length and two output length signals.
